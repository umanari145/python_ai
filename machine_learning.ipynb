# %% [markdown]
# <a href="https://colab.research.google.com/github/umanari145/python_ai/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
機械学習

1 次の選択肢の中から機械学習の選択肢として誤ったものを選んでください

a 機械学習とは過去のデータから学習をすることによってデータの背景やパターンを知る方法である。
b 機械学習では数学(線形代数、微積分、統計学)のロジックが使われている
c 機会数学では有識者の意見をもとにロジックを組み立てていく必要がある。
d 機械学習の実装に関してはPython,Rなどの言語が使われることが多い。

答え c

2 次の中で機械学習に適さない問題の選択肢はどれか

a 大量のデータの特徴や法則を捉え、未知のデータを予測・分類する。
b 分析の精度は１００%ではないが向上させることができる。
c 目的に応じて手法を使い分ける必要がある。
d 喜怒哀楽を感じたり、自発的に考えること

答え d

3 次の選択肢の中でそれぞれの手法と一致する選択肢を選んでください。

教師あり学習
教師なし学習
強化学習
機械学習には適さない

a 学習データに正解を与えない状態で学習させる学習手法である。
b コンピューターエージェントが動的環境と、繰り返し試行錯誤のやりとりを重ねることによってタスクを実行できるようになる手法である。
c 学習データに正解を与えた状態で学習させる手法である。
d 有識者の意見をもとに正解を導く方法である。

答え
教師あり学習 c
教師なし学習 a
強化学習 b
機械学習には適さない d

4 以下の選択肢の中で、機械学習の分類と一致する選択肢を選んでください。

回帰
分類

a 画像データから、その画像のカテゴリである画像ラベルを学習する
b 駅からの距離、間取り、・・などの情報から家賃を予測する
c 出航した広告予算情報から、広告経由での売上金額を学習する
d 過去の売上データから購買者と非購買者を予測する
e 日本語の文章データからそのテキストの記事のカテゴリを予測する

答え
回帰 b,c
分類 a,d,e

5 次の選択肢の中から、説明変数、目的変数の説明として誤ったものを選んでください。

a 「駅からの距離、間取り、・・などの情報から家賃を予測する」ケースの場合、家賃が目的変数、それ以外の変数が説明変数である
b 説明変数は「何かの原因となっている変数」のことで、目的変数は「その原因を受けて発生した結果となっている変数」のことである
c 似た表現として、目的変数を「独立変数」、説明変数を「従属変数」ということもある。
d 目的変数と説明変数の関係を数学的に表現したものが回帰分析となる

答え c

6 次の選択肢の中から、機械学習の手法の説明として誤ったものを選んでください。

a 「駅からの距離、間取り、・・などの情報から家賃を予測する」ケースの場合、家賃に対して複数の変数が関わってくるため、単回帰分析となる。
b 過去の売上データから購買者と非購買者を予測するといったような解が2値になるような問題の場合、「ロジスティック回帰分析」の手法が使われることがある。
c 顧客データをいくつかのクラスタに分けるような問題の場合、k-means法が用いられることが多い。
d 重回帰分析と単回帰分析の違いは、説明変数の数が単一か複数かの違いである。

答え a
