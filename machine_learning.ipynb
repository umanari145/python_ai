# %% [markdown]
# <a href="https://colab.research.google.com/github/umanari145/python_ai/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
機械学習

次の選択肢の中から正しいものを選んでください

機械学習とは[]から学習をすることによってデータの背景やパターンを知る方法である。

1 
2 過去のデータ
3 有識者の意見
4

次の中で機械学習に適さない問題の選択肢はどれか

1 大量のデータの特徴や法則を捉え、未知のデータを予測・分類する。
2 分析の精度は１００%ではないが向上させることができる。
3 目的に応じて手法を使い分ける必要がある。
4 喜怒哀楽を感じたり、自発的に考えること

次の選択肢の中でそれぞれの手法と一致する選択肢を選んでください。

教師あり学習
教師なし学習
強化学習

1 学習データに正解を与えない状態で学習させる学習手法である。
2 コンピューターエージェントが動的環境と、繰り返し試行錯誤のやりとりを重ねることによってタスクを実行できるようになる手法である。
3 学習データに正解を与えた状態で学習させる手法である。
4 有識者の意見をもとに正解を導く方法である。


以下の選択肢の中で、機械学習の分類と一致する選択肢を選んでください。

回帰
分類

1 画像データから、その画像のカテゴリである画像ラベルを学習する
2 駅からの距離、間取り、・・などの情報から家賃を予測する
3 出航した広告予算情報から、広告経由での売上金額を学習する
4 過去の売上データから購買者と非購買者を予測する
5 日本語の文章データからそのテキストの記事のカテゴリを予測する

次の選択肢の中から、説明変数、目的変数の説明として誤ったものを選んでください。

「駅からの距離、間取り、・・などの情報から家賃を予測する」ケースの場合、家賃が目的変数、それ以外の変数が説明変数である
説明変数は「何かの原因となっている変数」のことで、目的変数は「その原因を受けて発生した結果となっている変数」のことである
似た表現として、目的変数を「独立変数」、説明変数を「従属変数」ということもある。
